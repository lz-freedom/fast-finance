# %%
pip install yfinance==1.0.0
# Out:
# Collecting yfinance==1.0.0
#   Downloading yfinance-1.0-py2.py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from yfinance==1.0.0) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.12/dist-packages (from yfinance==1.0.0) (2.0.2)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.12/dist-packages (from yfinance==1.0.0) (2.32.4)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance==1.0.0) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from yfinance==1.0.0) (4.5.1)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.12/dist-packages (from yfinance==1.0.0) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.12/dist-packages (from yfinance==1.0.0) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.12/dist-packages (from yfinance==1.0.0) (3.18.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.12/dist-packages (from yfinance==1.0.0) (4.13.5)
# Requirement already satisfied: curl_cffi<0.14,>=0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance==1.0.0) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from yfinance==1.0.0) (5.29.5)
# Requirement already satisfied: websockets>=13.0 in /usr/local/lib/python3.12/dist-packages (from yfinance==1.0.0) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.11.1->yfinance==1.0.0) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.11.1->yfinance==1.0.0) (4.15.0)
# Requirement already satisfied: cffi>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from curl_cffi<0.14,>=0.7->yfinance==1.0.0) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in /usr/local/lib/python3.12/dist-packages (from curl_cffi<0.14,>=0.7->yfinance==1.0.0) (2025.11.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->yfinance==1.0.0) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->yfinance==1.0.0) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance==1.0.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance==1.0.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance==1.0.0) (2.5.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12.0->curl_cffi<0.14,>=0.7->yfinance==1.0.0) (2.23)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance==1.0.0) (1.17.0)
# Downloading yfinance-1.0-py2.py3-none-any.whl (127 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.1/127.1 kB 3.6 MB/s eta 0:00:00
# Installing collected packages: yfinance
#   Attempting uninstall: yfinance
#     Found existing installation: yfinance 0.2.66
#     Uninstalling yfinance-0.2.66:
#       Successfully uninstalled yfinance-0.2.66
# Successfully installed yfinance-1.0

# %%
import yfinance as yf
from yfinance import EquityQuery

proxy_url = "http://bdz_dc_5238-f-1-country-us:VLmfQTP9qq4SbRNH@proxy-na.socks5.io:3000"
yf.config.network.proxy = {"http": proxy_url, "https": proxy_url}
yf.config.network.retries = 3

# %%
# 国家地区列表
regions = ["us", "cn", "sg", "hk", "in"]
# 盘中市值最小值
minIntradayMarketCap = 20000000
# 日交易量最小值
minDayVolume = 5000000
# 交易所
exchanges = ['SHH','SHZ','HKG','NYQ','NMS','SES','JPX','NSI','LSE','TOR','VAN','ASX']
# 不同国家地区返回股票条数
size = 25

data = {}
for region in regions:
    query = EquityQuery("and", [
        EquityQuery("eq", ["region", region]),
        EquityQuery("gte", ["intradaymarketcap", minIntradayMarketCap]),
        EquityQuery("gt", ["dayvolume", minDayVolume]),
        EquityQuery("is-in", ['exchange', *exchanges])
    ])
    resp = yf.screen(
        query,
        size=size,
        sortField="dayvolume",
        sortAsc=False
    )
    print(region)

    list = []
    for q in resp["quotes"]:
        print(q.get("symbol"), "|", q.get("displayName"), "|",q.get("shortName"),"|", q.get("prevName"))
        list.append(q)

    data[region] = list
print(data["us"][0])
# Out:
# us
# NVDA | NVIDIA | NVIDIA Corporation | Usual Stablecoin
# ALMS | Alumis | Alumis Inc. | None
# SOFI | SoFi | SoFi Technologies, Inc. | Social Capital Hedosophia Holdings Corp. V
# TSLA | Tesla | Tesla, Inc. | None
# SMR | NuScale Power | NuScale Power Corporation | None
# BYND | Beyond Meat | Beyond Meat, Inc. | None
# BBAI | BigBear.ai | BigBear.ai, Inc. | BigBear.ai Holdings
# AAL | American Airlines | American Airlines Group, Inc. | None
# INTC | Intel | Intel Corporation | None
# MU | Micron Technology | Micron Technology, Inc. | None
# NIO | NIO | NIO Inc. | None
# NU | Nu | Nu Holdings Ltd. | None
# FCX | Freeport-McMoRan | Freeport-McMoRan, Inc. | None
# IMSR | Terrestrial Energy | Terrestrial Energy Inc. | None
# VALE | Vale | VALE S.A. | None
# NVO | None | Novo Nordisk A/S | None
# PFE | Pfizer | Pfizer, Inc. | None
# NFLX | Netflix | Netflix, Inc. | VIVEK
# F | None | Ford Motor Company | None
# TE | T1 Energy | T1 Energy Inc. | FREYR Battery
# ETERNAL.NS | None | ETERNAL LIMITED | Zomato Limited
# TATASTEEL.NS | None | TATA STEEL LIMITED | None
# SWIGGY.NS | None | SWIGGY LIMITED | None
# SAIL.NS | None | STEEL AUTHORITY OF INDIA | None
# RELIANCE.NS | None | RELIANCE INDUSTRIES LTD | None
# UNIONBANK.NS | None | UNION BANK OF INDIA | None
# {'language': 'en-US', 'region': 'US', 'quoteType': 'EQUITY', 'typeDisp': 'Equity', 'quoteSourceName': 'Nasdaq Real Time Price', 'triggerable': True, 'customPriceAlertConfidence': 'HIGH', 'regularMarketChangePercent': 0.9568377, 'currency': 'USD', 'corporateActions': [], 'esgPopulated': False, 'tradeable': False, 'cryptoTradeable': False, 'hasPrePostMarketData': True, 'firstTradeDateMilliseconds': 917015400000, 'priceHint': 2, 'regularMarketChange': 1.800003, 'regularMarketTime': 1767714427, 'regularMarketPrice': 189.92, 'regularMarketDayHigh': 192.174, 'regularMarketDayRange': '188.98 - 192.174', 'regularMarketDayLow': 188.98, 'regularMarketVolume': 57233015, 'regularMarketPreviousClose': 188.12, 'bidSize': 1, 'askSize': 1, 'market': 'us_market', 'messageBoardId': 'finmb_32307', 'fullExchangeName': 'NasdaqGS', 'longName': 'NVIDIA Corporation', 'regularMarketOpen': 190.43, 'averageDailyVolume3Month': 186223122, 'averageDailyVolume10Day': 150282650, 'fiftyTwoWeekLowChange': 103.299995, 'fiftyTwoWeekLowChangePercent': 1.1925651, 'fiftyTwoWeekRange': '86.62 - 212.19', 'fiftyTwoWeekHighChange': -22.270004, 'fiftyTwoWeekHighChangePercent': -0.104953125, 'fiftyTwoWeekChangePercent': 34.237194, 'dividendDate': 1766707200, 'earningsTimestamp': 1772053200, 'earningsTimestampStart': 1772053200, 'earningsTimestampEnd': 1772053200, 'earningsCallTimestampStart': 1763589600, 'earningsCallTimestampEnd': 1763589600, 'isEarningsDateEstimate': False, 'trailingAnnualDividendRate': 0.04, 'trailingPE': 47.0099, 'dividendRate': 0.04, 'trailingAnnualDividendYield': 0.00021263024, 'marketState': 'REGULAR', 'epsTrailingTwelveMonths': 4.04, 'epsForward': 7.56654, 'epsCurrentYear': 4.69153, 'priceEpsCurrentYear': 40.48146, 'sharesOutstanding': 24305000000, 'bookValue': 4.892, 'fiftyDayAverage': 186.668, 'fiftyDayAverageChange': 3.251999, 'fiftyDayAverageChangePercent': 0.017421298, 'twoHundredDayAverage': 160.84785, 'twoHundredDayAverageChange': 29.072144, 'twoHundredDayAverageChangePercent': 0.18074313, 'forwardPE': 25.09998, 'priceToBook': 38.822567, 'sourceInterval': 15, 'exchangeDataDelayedBy': 0, 'exchangeTimezoneName': 'America/New_York', 'exchangeTimezoneShortName': 'EST', 'gmtOffSetMilliseconds': -18000000, 'prevName': 'Usual Stablecoin', 'nameChangeDate': '2026-01-05', 'bid': 171.04, 'exchange': 'NMS', 'fiftyTwoWeekHigh': 212.19, 'fiftyTwoWeekLow': 86.62, 'averageAnalystRating': '1.3 - Strong Buy', 'dividendYield': 0.02, 'financialCurrency': 'USD', 'shortName': 'NVIDIA Corporation', 'ask': 171.64, 'marketCap': 4623982133248, 'displayName': 'NVIDIA', 'symbol': 'NVDA'}
